# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
sentences = [
    "i am good",
    "i am happy",
    "happy today",
    "i am sad"
]
def preprocess_text(sentences):
    
    cleaned_sentences = []
    eng_stopwords = stopwords.words("english")
    for i in sentences:
        temp = i.split()
        for j in temp:
            if j not in eng_stopwords:
              cleaned_sentences.append(j)  
    return cleaned_sentences

cleaned_text = preprocess_text(sentences)
print(cleaned_text)
#expected output :
# [ 
# "good", "happy","happy today","sad"
# ]
# Out:
# ['good', 'happy', 'happy', 'today', 'sad']

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
sentences = [
    "i am good",
    "i am happy",
    "happy today",
    "i am sad"
]
def preprocess_text(sentences):
    cleaned_sentences = []
    
    text = sentences.lower()
    Print("After Lowercase: ",text)

    tokens = word_tokenize(text)
    print("Tokens: ",tokens)

    punctuation_filter = [word for word in tokens if word not in punc]
    print("Removed Punctuations:" , punctuation_filter)

    eng_stopwords = stopwords.words("english")
    filtered_tokens = [word for word in punctuation_filter if word not in eng_stopwords]
    print("Removed stopwords :", filtered_tokens)

    wnet = WordNetLemmatizer()
    lemmatized_words = []
    for word in filtered_tokens :
       cleaned_sentences.append(wnet.lemmatize(word,"v"))

    print("Lemmatization : ",lemmatized_words)

    cleaned_text = " ".join(lemmatized_words)
    print("Cleaned Text:",cleaned_text)
    
    
    return cleaned_sentences

cleaned_text = preprocess_text(sentences)
print(cleaned_text)
# sentences =
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 39
#      34     print("Cleaned Text:",cleaned_text)
#      37     return cleaned_sentences
# ---> 39 cleaned_text = preprocess_text(sentences)
#      40 print(cleaned_text)
#      41 # sentences =
#
# Cell In[14], line 13, in preprocess_text(sentences)
#      10 def preprocess_text(sentences):
#      11     cleaned_sentences = []
# ---> 13     text = sentences.lower()
#      14     Print("After Lowercase: ",text)
#      16     tokens = word_tokenize(text)
#
# AttributeError: 'list' object has no attribute 'lower'
